# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# In this assignment, we will work on the stock prices dataset named "prices.csv". Task is to create a Neural Network to classify closing price for a stock based on some parameters.

# %%
# Initialize the random number generator
import random
random.seed(0)

# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file using GUI if you are using google colab

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b493edf4-f2d6-4b37-9845-b22cc1c486ee" name="files[]" multiple disabled />
#      <output id="result-b493edf4-f2d6-4b37-9845-b22cc1c486ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %%
# run this cell to to mount the google drive if you are using google colab

from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df = pd.read_csv('prices.csv')

# %% [markdown]
# ### Drop null
# - Drop null values if any

# %%
df = df.dropna()

# %% [markdown]
# ### Drop columnns
# - Now, we don't need "date", "volume" and "symbol" column
# - drop "date", "volume" and "symbol" column from the data

# %%
df = df.drop(['date', 'symbol', 'volume'], axis=1)

# %% [markdown]
# ### Print the dataframe
# - print the modified dataframe

# %%
df.head()
# Out:
#          open       close         low        high
# 0  123.430000  125.839996  122.309998  126.250000
# 1  125.239998  119.980003  119.940002  125.540001
# 2  116.379997  114.949997  114.930000  119.739998
# 3  115.480003  116.620003  113.500000  117.440002
# 4  117.010002  114.970001  114.089996  117.330002

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Let's separate labels and features now. We are going to predict the value for "close" column so that will be our label. Our features will be "open", "low", "high"
# - Take "open" "low", "high" columns as features
# - Take "close" column as label

# %%
X = df.drop('close', axis=1)
y = df['close']

# %% [markdown]
# ### Create train and test sets
# - Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state= 12)

# %% [markdown]
# ### Scaling
# - Scale the data (features only)
# - Use StandarScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Convert data to NumPy array
# - Convert features and labels to numpy array

# %%
import numpy as np
# X_train = np.asarray(X_train)
# X_test = np.asarray(X_test)

y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ### Reshape features
# - Reshape the features to make it suitable for input in the model

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Define Model
# - Initialize a Sequential model
# - Add a Flatten layer
# - Add a Dense layer with one neuron as output
#   - add 'linear' as activation function

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
model = Sequential([
                    Flatten(),
                    Dense(1, activation='linear')
])

# %% [markdown]
# ### Compile the model
# - Compile the model
# - Use "sgd" optimizer
# - for calculating loss, use mean squared error

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ### Fit the model
# - epochs: 50
# - batch size: 128
# - specify validation data

# %%
model.fit(X_train, y_train, epochs=50, batch_size=128, validation_data=(X_test, y_test))
# Out:
# Train on 519843 samples, validate on 173282 samples
# Epoch 1/50
# 519843/519843 [==============================] - 8s 15us/sample - loss: 41.7010 - val_loss: 0.9034
# Epoch 2/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8817 - val_loss: 0.9088
# Epoch 3/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8756 - val_loss: 0.9104
# Epoch 4/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8726 - val_loss: 0.8856
# Epoch 5/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8655 - val_loss: 0.8745
# Epoch 6/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8603 - val_loss: 0.9045
# Epoch 7/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8562 - val_loss: 0.8753
# Epoch 8/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8481 - val_loss: 0.8565
# Epoch 9/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8445 - val_loss: 0.8678
# Epoch 10/50
# 519843/519843 [==============================] - 8s 15us/sample - loss: 0.8386 - val_loss: 0.8555
# Epoch 11/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8342 - val_loss: 0.8619
# Epoch 12/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8291 - val_loss: 0.8397
# Epoch 13/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8242 - val_loss: 0.8305
# Epoch 14/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8181 - val_loss: 0.8270
# Epoch 15/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8134 - val_loss: 0.8243
# Epoch 16/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8081 - val_loss: 0.8181
# Epoch 17/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.8047 - val_loss: 0.8130
# Epoch 18/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7997 - val_loss: 0.8140
# Epoch 19/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7944 - val_loss: 0.9310
# Epoch 20/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7900 - val_loss: 0.8054
# Epoch 21/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7850 - val_loss: 0.7947
# Epoch 22/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7819 - val_loss: 0.7959
# Epoch 23/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7771 - val_loss: 0.7831
# Epoch 24/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7705 - val_loss: 0.7998
# Epoch 25/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7672 - val_loss: 0.7750
# Epoch 26/50
# 519843/519843 [==============================] - 8s 14us/sample - loss: 0.7627 - val_loss: 0.8411
# Epoch 27/50
# 519843/519843 [==============================] - 8s 16us/sample - loss: 0.7586 - val_loss: 0.7655
# Epoch 28/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7547 - val_loss: 0.7631
# Epoch 29/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7501 - val_loss: 0.8022
# Epoch 30/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7463 - val_loss: 0.7552
# Epoch 31/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7420 - val_loss: 0.7518
# Epoch 32/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7381 - val_loss: 0.7512
# Epoch 33/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7328 - val_loss: 0.7427
# Epoch 34/50
# 519843/519843 [==============================] - 8s 15us/sample - loss: 0.7300 - val_loss: 0.7377
# Epoch 35/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7275 - val_loss: 0.7329
# Epoch 36/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7226 - val_loss: 0.7405
# Epoch 37/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7195 - val_loss: 0.7353
# Epoch 38/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7145 - val_loss: 0.7219
# Epoch 39/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7108 - val_loss: 0.7183
# Epoch 40/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7073 - val_loss: 0.7158
# Epoch 41/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7039 - val_loss: 0.7230
# Epoch 42/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.7011 - val_loss: 0.7095
# Epoch 43/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6964 - val_loss: 0.7032
# Epoch 44/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6915 - val_loss: 0.7010
# Epoch 45/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6892 - val_loss: 0.7031
# Epoch 46/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6858 - val_loss: 0.6925
# Epoch 47/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6824 - val_loss: 0.7159
# Epoch 48/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6793 - val_loss: 0.6859
# Epoch 49/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6746 - val_loss: 0.6857
# Epoch 50/50
# 519843/519843 [==============================] - 7s 14us/sample - loss: 0.6728 - val_loss: 0.6794

# %% [markdown]
# ### Evaluate the model
# - Evaluate the model on test data

# %%
model.evaluate(X_test, y_test)
# Out:
# 173282/173282 [==============================] - 6s 32us/sample - loss: 0.6794
# 0.6793999467196418

# %% [markdown]
# ### Manual predictions
# - Test the predictions on manual inputs
# - We have scaled out training data, so we need to transform our custom inputs using the object of the scaler
# - Example of manual input: [123.430000,	122.30999, 116.250000]

# %%
model.predict(sc.transform([[123.430000,	122.30999, 116.250000]]))
# Out:
# array([[119.81726]], dtype=float32)

# %% [markdown]
# # Build a DNN

# %% [markdown]
# ### Collect Fashion mnist data from tf.keras.datasets

# %%
import tensorflow as tf
(trainX, trainY),(testX, testY) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ### Change train and test labels into one-hot vectors

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %% [markdown]
# ### Build the Graph

# %% [markdown]
# ### Initialize model, reshape & normalize data

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# ### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Hidden layers
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dense(100, activation='relu'))

#Dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Train the model
model.fit(trainX,trainY,          
          validation_data=(testX,testY),
          epochs=5, batch_size=32)
